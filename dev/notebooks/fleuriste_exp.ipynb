# %% [markdown]
# # 📘 Modèle Pyomo généré automatiquement

# %%
from pyomo.environ import *
from pyomo.opt import SolverFactory

# %% [markdown]
# ## Définition du modèle

# %%
from pyomo.environ import *

model = ConcreteModel()

model.X1 = Var(domain=NonNegativeReals)
model.X2 = Var(domain=NonNegativeReals)
model.c0 = Constraint(expr=10 * model.X1 + 10 * model.X2 <= 50)
model.c1 = Constraint(expr=10 * model.X1 + 20 * model.X2 <= 80)
model.c2 = Constraint(expr=20 * model.X1 + 10 * model.X2 <= 80)
model.obj = Objective(expr=40 * model.X1 + 50 * model.X2, sense=maximize)

# %% [markdown]
# ## Résolution du modèle

# %%
solver = SolverFactory('highs')  # change selon ce que tu as installé
result = solver.solve(model, tee=True)
print('Solver status:', result.solver.status)
print('Termination condition:', result.solver.termination_condition)
# Out:
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# LP has 3 rows; 2 cols; 6 nonzeros
# Coefficient ranges:
#   Matrix  [1e+01, 2e+01]
#   Cost    [4e+01, 5e+01]
#   Bound   [0e+00, 0e+00]
#   RHS     [5e+01, 8e+01]
# Presolving model
# 3 rows, 2 cols, 6 nonzeros  0s
# 3 rows, 2 cols, 6 nonzeros  0s
# Presolve reductions: rows 3(-0); columns 2(-0); nonzeros 6(-0) - Not reduced
# Problem not reduced by presolve: solving the LP
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -5.6249927791e+00 Ph1: 3(6.25); Du: 2(5.62499) 0s
#           2     2.3000000000e+02 Pr: 0(0) 0s
#
# Model status        : Optimal
# Simplex   iterations: 2
# Objective value     :  2.3000000000e+02
# P-D objective error :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solver status: ok
# Termination condition: optimal

# %% [markdown]
# ## Valeurs optimales des variables

# %%
for v in model.component_objects(Var, active=True):
    print(f'Variable set: {v}')
    for index in v:
        print(f'   {index} = {v[index].value}')

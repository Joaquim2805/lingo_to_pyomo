# %% [markdown]
# # 📘 Modèle Pyomo généré automatiquement

# %% [markdown]
# ## 📦 Imports

# %%
from pyomo.environ import *
from pyomo.opt import SolverFactory
import pandas as pd

# %% [markdown]
# ## 💾 Chargement des données
# Les données `.dat` sont chargées nativement par Pyomo via `model.create_instance(...)` dans la section du modèle.

# %% [markdown]
# ## 🔹 Model

# %%
from pyomo.environ import *

model = AbstractModel()

# %% [markdown]
# ## 🔹 Sets

# %%
model.PRODUITS = Set()
model.USINES = Set()
model.PRODS_USINES = Set(dimen=2, initialize=lambda m: [(i,j) for i in m.USINES for j in m.PRODUITS])

# %% [markdown]
# ## 🔹 Parameters

# %%
model.gain = Param(model.PRODUITS, within=NonNegativeReals)
model.disp = Param(model.USINES, within=NonNegativeReals)
model.utilisation = Param(model.USINES, model.PRODUITS, within=NonNegativeReals)

# %% [markdown]
# ## 🔹 Variables

# %%
model.x = Var(model.PRODUITS, domain=NonNegativeReals)

# %% [markdown]
# ## 🔹 Data

# %%
model = model.create_instance('../data/WINDOR_OLE_data.dat')

# %% [markdown]
# ## 🔹 Constraints

# %%
model.c_for_0 = ConstraintList()
for u in model.USINES:
    model.c_for_0.add(sum(model.utilisation[u,p] * model.x[p] for p in model.PRODUITS) <= model.disp[u])

# %% [markdown]
# ## 🔹 Objective

# %%
model.obj = Objective(expr=sum(model.gain[p] * model.x[p] for p in model.PRODUITS), sense=maximize)

# %% [markdown]
# ## ⚙️ Résolution du modèle

# %%
solver = SolverFactory('highs')
result = solver.solve(model, tee=True)

print('✅ Solver status:', result.solver.status)
print('✅ Termination condition:', result.solver.termination_condition)
# Out:
# ✅ Solver status: ok
# ✅ Termination condition: optimal

# %% [markdown]
# ## 🎯 Valeur de la fonction objective

# %%
for obj in model.component_objects(Objective, active=True):
    print(f'Objectif: {obj.name}')
    print(f'Valeur optimale: {obj():.4f}')
    print(f'Sens: {"Minimisation" if obj.sense == minimize else "Maximisation"}')
# Out:
# Objectif: obj
# Valeur optimale: 36.0000
# Sens: Maximisation

# %% [markdown]
# ## 📊 Valeurs optimales des variables

# %%
# Extraction des résultats dans un DataFrame
results_data = []
for v in model.component_objects(Var, active=True):
    for index in v:
        results_data.append({
            'Variable': v.name,
            'Index': str(index) if index != None else '-',
            'Valeur': v[index].value
        })

df_results = pd.DataFrame(results_data)
# Filtrer les valeurs non-nulles pour plus de clarté
df_results = df_results[df_results['Valeur'].notna()]
df_results = df_results[df_results['Valeur'] != 0]
df_results.style.format({'Valeur': '{:.4f}'}).set_caption('Variables de décision optimales')
# Out:
# <style type="text/css">
# </style>
# <table id="T_af5e7">
#   <caption>Variables de décision optimales</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af5e7_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_af5e7_level0_col1" class="col_heading level0 col1" >Index</th>
#       <th id="T_af5e7_level0_col2" class="col_heading level0 col2" >Valeur</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af5e7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_af5e7_row0_col0" class="data row0 col0" >x</td>
#       <td id="T_af5e7_row0_col1" class="data row0 col1" >P1</td>
#       <td id="T_af5e7_row0_col2" class="data row0 col2" >2.0000</td>
#     </tr>
#     <tr>
#       <th id="T_af5e7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_af5e7_row1_col0" class="data row1 col0" >x</td>
#       <td id="T_af5e7_row1_col1" class="data row1 col1" >P2</td>
#       <td id="T_af5e7_row1_col2" class="data row1 col2" >6.0000</td>
#     </tr>
#   </tbody>
# </table>
